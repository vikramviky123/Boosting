# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import zipfile

zip_file_path = "dataset/playground-series-s3e3.zip"
extracted_path = "dataset/"

with zipfile.ZipFile(zip_file_path,"r") as zip_ref:
    zip_ref.extractall(extracted_path)
    
print("Zip file Extracted")

# %%
df = pd.read_csv("dataset/train.csv")
test = pd.read_csv("dataset/test.csv")
df.head()
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 1
# 1                        1  ...            80                 1
# 2                        3  ...            80                 2
# 3                        3  ...            80                 0
# 4                        2  ...            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 10                      2               3              10
# 1                  4                      3               3               4
# 2                  4                      3               3               3
# 3                 15                      1               1               6
# 4                 31                      0               3              31
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                  0                        7                     8          0
# 1                  2                        0                     3          0
# 2                  2                        1                     2          0
# 3                  0                        0                     2          0
# 4                 14                        4                    10          1
#
# [5 rows x 35 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == "O":
        le.fit(df[col])
        df[col] = le.transform(df[col])
        test[col] = le.transform(test[col])

# %%
x_cols = [col for col in df.columns if col not in ["id","Attrition"]]
y_cols = ["Attrition"]

# %%
att = df[df["Attrition"] == 1]
dff = pd.concat([df,att,att,att], axis = 0)

# Shuffle the DataFrame
shuffled_df = dff.sample(frac=1.0, random_state=42)

# Reset the index if needed
shuffled_df.reset_index(drop=True, inplace=True)

# %%
X = df[x_cols]
y = df[y_cols]

# %%
Xd = shuffled_df[x_cols]
xtest = test[x_cols]
yd = shuffled_df[y_cols]

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier, HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import xgboost as xgb
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
import optuna

# %%
def cross_validation(X,y,params,n_splits, xtest=None):

    skf = StratifiedKFold(n_splits=n_splits, random_state=42, shuffle=True)

    acc_scr = []
    f1_scr = []
    auc_scr = []
    eval_results_ = {}
    
    if xtest is not None:
        preds = np.zeros(len(xtest))
    else:
        preds = None

    for i, (train_index, test_index) in enumerate(skf.split(X, y)):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Dmatrix train and Test dataset        
        dtrain = lgb.Dataset(X_train, label=y_train)
        dvalid = lgb.Dataset(X_test, label=y_test)
        
        
        
        model = lgb.train(params = params,
                          train_set = dtrain,
                          valid_sets=[dtrain, dvalid],
                          verbose_eval =False,
                          callbacks = [early_stopping(100), log_evaluation(100)])

        y_preds = np.rint(model.predict(X_test))     
         

        if xtest is not None:
            test_preds = model.predict(xtest) / n_splits
            if preds is None:
                preds = test_preds
            else:
                preds += test_preds

        acc_scr.append(accuracy_score(y_test, y_preds))
        f1_scr.append(f1_score(y_test, y_preds))
        auc_scr.append(roc_auc_score(y_test, model.predict(X_test, num_iteration=model.best_iteration)))

    avg_acc = round(np.mean(acc_scr), 4)
    avg_f1 = round(np.mean(f1_scr), 4)
    avg_roc = round(np.mean(auc_scr), 4)

    print(f"Average of {n_splits} splits accuracy score : {avg_acc:.4f} | f1 score : {avg_f1:.4f} | roc score : {avg_roc:.4f}")

    return avg_roc, preds

# %% [markdown]
#         "verbose" :-1,
#         "force_col_wise":True,
#         "boosting_type": trial.suggest_categorical('boosting_type',['gbdt','dart','goss']),
#         'num_iterations' : trial.suggest_int('num_iterations',200,500,step=50),
#         "num_leaves": trial.suggest_int("num_leaves", 3, 10),
#         "max_depth": trial.suggest_int("max_depth", 3, 5),
#         "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.5,log=True),
#         'scale_pos_weight': trial.suggest_int('scale_pos_weight',2,7),
#         'colsample_bytree' :trial.suggest_float('colsample_bytree',0.5,0.8,step=0.1),
#         'reg_alpha' : trial.suggest_int('reg_alpha',2,10,step=1),
#         'reg_lambda' : trial.suggest_int('reg_lambda',2,10,step=1),
#         #"bagging_fraction": trial.suggest_float("bagging_fraction", 0.5, 1.0),
#         #"bagging_freq": trial.suggest_int("bagging_freq", 1, 8),
#         'n_jobs' : -1,
#         'metric': 'AUC',
#         'verbose': 0

# %%
# %%time

optuna.logging.set_verbosity(optuna.logging.WARNING)

base_params = { "objective": "binary",
                    "metric": "auc",
                    "verbose": -1,
                    "random_state" : 42,
                    "force_col_wise":True
                    }

def objective_pr(trial):
        
    params = {
                "boosting_type": trial.suggest_categorical('boosting_type',['gbdt','dart','rf']),
                # alias reg_alpha
                "reg_alpha": trial.suggest_float("reg_alpha", 1e-2, 10.0),
                # alias reg_lmabda
                "reg_lambda": trial.suggest_float("reg_lambda", 1e-2, 10.0),
                "learning_rate": trial.suggest_float("learning_rate", 1e-2, 0.9),
                
                # Num of boosting rounds
                "n_estimators": trial.suggest_int("n_estimators", 200, 5000, step = 100),
                # increase for better score/will overfit default = 31
                "num_leaves": trial.suggest_int("num_leaves", 3, 10, step = 1),
                # depth of tree, -1 for full depth
                "max_depth": trial.suggest_int("max_depth", 3, 5, step = 1),
                "min_child_samples": trial.suggest_int("min_child_samples", 20, 200, step = 5),
                'scale_pos_weight': trial.suggest_int('scale_pos_weight',2,7, step = 1),
                
                # alias colsample_bytree, basically number of columns
                "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 0.95, step = 0.1),
                # alias subsample, fraction of sample of whole train data
                "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 0.94, step = 0.1),
                # alias subsample_freq after how many iters get smaple again
                "bagging_freq": trial.suggest_int("bagging_freq", 3, 10, step = 1)
    }
    
    params.update(base_params)
    
    scores = cross_validation(X, y, params, 5, xtest=None)[0]
    return np.mean(scores)

study = optuna.create_study(direction='maximize')
study.optimize(objective_pr, n_trials=5)
best_params = study.best_params
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.796081	valid_1's auc: 0.720904
# [200]	training's auc: 0.801818	valid_1's auc: 0.733024
# [300]	training's auc: 0.803408	valid_1's auc: 0.740752
# [400]	training's auc: 0.802535	valid_1's auc: 0.739696
# Early stopping, best iteration is:
# [328]	training's auc: 0.804112	valid_1's auc: 0.742145
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.79511	valid_1's auc: 0.843877
# Early stopping, best iteration is:
# [34]	training's auc: 0.793885	valid_1's auc: 0.854223
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.810559	valid_1's auc: 0.727076
# Early stopping, best iteration is:
# [97]	training's auc: 0.810612	valid_1's auc: 0.727246
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.799268	valid_1's auc: 0.746441
# [200]	training's auc: 0.801198	valid_1's auc: 0.748475
# [300]	training's auc: 0.802401	valid_1's auc: 0.752415
# Early stopping, best iteration is:
# [268]	training's auc: 0.801782	valid_1's auc: 0.752669
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.783656	valid_1's auc: 0.825636
# Early stopping, best iteration is:
# [42]	training's auc: 0.781895	valid_1's auc: 0.832881
# Average of 5 splits accuracy score : 0.7674 | f1 score : 0.3912 | roc score : 0.7818
# [100]	training's auc: 0.916739	valid_1's auc: 0.786824
# [200]	training's auc: 0.930028	valid_1's auc: 0.771537
# [300]	training's auc: 0.937108	valid_1's auc: 0.801182
# [400]	training's auc: 0.941591	valid_1's auc: 0.799831
# [500]	training's auc: 0.952191	valid_1's auc: 0.797044
# [600]	training's auc: 0.95914	valid_1's auc: 0.794848
# [700]	training's auc: 0.965749	valid_1's auc: 0.784459
# [800]	training's auc: 0.968221	valid_1's auc: 0.777787
# [900]	training's auc: 0.977164	valid_1's auc: 0.782432
# [1000]	training's auc: 0.978821	valid_1's auc: 0.790372
# [1100]	training's auc: 0.981441	valid_1's auc: 0.793412
# [1200]	training's auc: 0.983414	valid_1's auc: 0.792568
# [1300]	training's auc: 0.98596	valid_1's auc: 0.807095
# [1400]	training's auc: 0.986944	valid_1's auc: 0.80397
# [100]	training's auc: 0.909992	valid_1's auc: 0.827618
# [200]	training's auc: 0.917686	valid_1's auc: 0.818919
# [300]	training's auc: 0.927508	valid_1's auc: 0.811233
# [400]	training's auc: 0.936108	valid_1's auc: 0.825169
# [500]	training's auc: 0.945613	valid_1's auc: 0.82103
# [600]	training's auc: 0.955869	valid_1's auc: 0.826182
# [700]	training's auc: 0.963204	valid_1's auc: 0.820439
# [800]	training's auc: 0.969914	valid_1's auc: 0.805321
# [900]	training's auc: 0.975868	valid_1's auc: 0.80625
# [1000]	training's auc: 0.976619	valid_1's auc: 0.801267
# [1100]	training's auc: 0.979096	valid_1's auc: 0.795608
# [1200]	training's auc: 0.982562	valid_1's auc: 0.805828
# [1300]	training's auc: 0.985436	valid_1's auc: 0.786402
# [1400]	training's auc: 0.985711	valid_1's auc: 0.779392
# [100]	training's auc: 0.912934	valid_1's auc: 0.755
# [200]	training's auc: 0.929997	valid_1's auc: 0.792203
# [300]	training's auc: 0.942756	valid_1's auc: 0.779237
# [400]	training's auc: 0.948779	valid_1's auc: 0.779068
# [500]	training's auc: 0.958138	valid_1's auc: 0.790085
# [600]	training's auc: 0.957556	valid_1's auc: 0.792542
# [700]	training's auc: 0.968216	valid_1's auc: 0.779831
# [800]	training's auc: 0.973593	valid_1's auc: 0.776186
# [900]	training's auc: 0.979362	valid_1's auc: 0.785085
# [1000]	training's auc: 0.981102	valid_1's auc: 0.778305
# [1100]	training's auc: 0.983048	valid_1's auc: 0.774576
# [1200]	training's auc: 0.984163	valid_1's auc: 0.771864
# [1300]	training's auc: 0.986136	valid_1's auc: 0.764661
# [1400]	training's auc: 0.987474	valid_1's auc: 0.772034
# [100]	training's auc: 0.901428	valid_1's auc: 0.847542
# [200]	training's auc: 0.919363	valid_1's auc: 0.839237
# [300]	training's auc: 0.93309	valid_1's auc: 0.816271
# [400]	training's auc: 0.941143	valid_1's auc: 0.835932
# [500]	training's auc: 0.948329	valid_1's auc: 0.821186
# [600]	training's auc: 0.955917	valid_1's auc: 0.813814
# [700]	training's auc: 0.961918	valid_1's auc: 0.806525
# [800]	training's auc: 0.966397	valid_1's auc: 0.807203
# [900]	training's auc: 0.974863	valid_1's auc: 0.805339
# [1000]	training's auc: 0.974683	valid_1's auc: 0.810678
# [1100]	training's auc: 0.978633	valid_1's auc: 0.807712
# [1200]	training's auc: 0.982413	valid_1's auc: 0.797627
# [1300]	training's auc: 0.982598	valid_1's auc: 0.812542
# [1400]	training's auc: 0.986633	valid_1's auc: 0.792797
# [100]	training's auc: 0.890831	valid_1's auc: 0.856441
# [200]	training's auc: 0.914647	valid_1's auc: 0.883729
# [300]	training's auc: 0.928167	valid_1's auc: 0.873051
# [400]	training's auc: 0.933413	valid_1's auc: 0.885678
# [500]	training's auc: 0.946478	valid_1's auc: 0.880847
# [600]	training's auc: 0.949376	valid_1's auc: 0.874831
# [700]	training's auc: 0.959555	valid_1's auc: 0.870847
# [800]	training's auc: 0.965926	valid_1's auc: 0.866102
# [900]	training's auc: 0.97169	valid_1's auc: 0.873136
# [1000]	training's auc: 0.975566	valid_1's auc: 0.867288
# [1100]	training's auc: 0.977951	valid_1's auc: 0.877373
# [1200]	training's auc: 0.981366	valid_1's auc: 0.873983
# [1300]	training's auc: 0.980166	valid_1's auc: 0.856695
# [1400]	training's auc: 0.983344	valid_1's auc: 0.856441
# Average of 5 splits accuracy score : 0.8432 | f1 score : 0.4402 | roc score : 0.8009
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.790434	valid_1's auc: 0.741047
# Early stopping, best iteration is:
# [63]	training's auc: 0.791167	valid_1's auc: 0.748142
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779678	valid_1's auc: 0.827069
# Early stopping, best iteration is:
# [33]	training's auc: 0.775413	valid_1's auc: 0.843539
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.794488	valid_1's auc: 0.711186
# [200]	training's auc: 0.797647	valid_1's auc: 0.716314
# [300]	training's auc: 0.796336	valid_1's auc: 0.717542
# [400]	training's auc: 0.797219	valid_1's auc: 0.719958
# Early stopping, best iteration is:
# [339]	training's auc: 0.798295	valid_1's auc: 0.725042
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.787487	valid_1's auc: 0.724407
# [200]	training's auc: 0.788568	valid_1's auc: 0.728644
# Early stopping, best iteration is:
# [129]	training's auc: 0.789298	valid_1's auc: 0.732797
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774146	valid_1's auc: 0.838347
# [200]	training's auc: 0.770231	valid_1's auc: 0.837034
# [300]	training's auc: 0.779143	valid_1's auc: 0.838941
# Early stopping, best iteration is:
# [240]	training's auc: 0.778855	valid_1's auc: 0.839661
# Average of 5 splits accuracy score : 0.8807 | f1 score : 0.0000 | roc score : 0.7778
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.999227	valid_1's auc: 0.771453
# Early stopping, best iteration is:
# [21]	training's auc: 0.964455	valid_1's auc: 0.793159
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.997751	valid_1's auc: 0.800338
# Early stopping, best iteration is:
# [9]	training's auc: 0.914209	valid_1's auc: 0.837373
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.998007	valid_1's auc: 0.745932
# Early stopping, best iteration is:
# [8]	training's auc: 0.912838	valid_1's auc: 0.771102
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.997647	valid_1's auc: 0.782034
# Early stopping, best iteration is:
# [10]	training's auc: 0.931165	valid_1's auc: 0.796441
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.997684	valid_1's auc: 0.826102
# Early stopping, best iteration is:
# [32]	training's auc: 0.983815	valid_1's auc: 0.839322
# Average of 5 splits accuracy score : 0.8145 | f1 score : 0.4157 | roc score : 0.8075
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.919359	valid_1's auc: 0.795017
# [200]	training's auc: 0.938818	valid_1's auc: 0.808953
# [300]	training's auc: 0.95362	valid_1's auc: 0.805152
# Early stopping, best iteration is:
# [219]	training's auc: 0.940866	valid_1's auc: 0.812753
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.915972	valid_1's auc: 0.841132
# Early stopping, best iteration is:
# [36]	training's auc: 0.870666	valid_1's auc: 0.851267
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.920606	valid_1's auc: 0.775847
# Early stopping, best iteration is:
# [54]	training's auc: 0.90183	valid_1's auc: 0.786186
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.913986	valid_1's auc: 0.852373
# Early stopping, best iteration is:
# [99]	training's auc: 0.913484	valid_1's auc: 0.854492
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.908867	valid_1's auc: 0.864407
# [200]	training's auc: 0.931879	valid_1's auc: 0.869915
# Early stopping, best iteration is:
# [174]	training's auc: 0.923884	valid_1's auc: 0.87322
# Average of 5 splits accuracy score : 0.8795 | f1 score : 0.4026 | roc score : 0.8356
# CPU times: total: 3min 6s
# Wall time: 45.6 s

# %% [markdown]
# {'boosting_type': 'goss',
#  'num_iterations': 350,
#  'num_leaves': 4,
#  'max_depth': 5,
#  'learning_rate': 0.138101890373062,
#  'scale_pos_weight': 2,
#  'colsample_bytree': 0.5,
#  'reg_alpha': 7,
#  'reg_lambda': 2}

# %%
best_params
# Out:
# {'boosting_type': 'gbdt',
#  'reg_alpha': 5.9843742075490685,
#  'reg_lambda': 9.70367924752612,
#  'learning_rate': 0.21054713557022756,
#  'n_estimators': 3200,
#  'num_leaves': 4,
#  'max_depth': 4,
#  'min_child_samples': 160,
#  'scale_pos_weight': 2,
#  'feature_fraction': 0.5,
#  'bagging_fraction': 0.7000000000000001,
#  'bagging_freq': 6}

# %%
best_params.update(base_params)

best_params
# Out:
# {'boosting_type': 'gbdt',
#  'reg_alpha': 5.9843742075490685,
#  'reg_lambda': 9.70367924752612,
#  'learning_rate': 0.21054713557022756,
#  'n_estimators': 3200,
#  'num_leaves': 4,
#  'max_depth': 4,
#  'min_child_samples': 160,
#  'scale_pos_weight': 2,
#  'feature_fraction': 0.5,
#  'bagging_fraction': 0.7000000000000001,
#  'bagging_freq': 6,
#  'objective': 'binary',
#  'metric': 'auc',
#  'verbose': -1,
#  'random_state': 42,
#  'force_col_wise': True}

# %%
cross_validation(X,y,best_params,5, None)
print("-"*50)
cross_validation(Xd,yd,best_params,5, None)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.919359	valid_1's auc: 0.795017
# [200]	training's auc: 0.938818	valid_1's auc: 0.808953
# [300]	training's auc: 0.95362	valid_1's auc: 0.805152
# Early stopping, best iteration is:
# [219]	training's auc: 0.940866	valid_1's auc: 0.812753
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.915972	valid_1's auc: 0.841132
# Early stopping, best iteration is:
# [36]	training's auc: 0.870666	valid_1's auc: 0.851267
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.920606	valid_1's auc: 0.775847
# Early stopping, best iteration is:
# [54]	training's auc: 0.90183	valid_1's auc: 0.786186
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.913986	valid_1's auc: 0.852373
# Early stopping, best iteration is:
# [99]	training's auc: 0.913484	valid_1's auc: 0.854492
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.908867	valid_1's auc: 0.864407
# [200]	training's auc: 0.931879	valid_1's auc: 0.869915
# Early stopping, best iteration is:
# [174]	training's auc: 0.923884	valid_1's auc: 0.87322
# Average of 5 splits accuracy score : 0.8795 | f1 score : 0.4026 | roc score : 0.8356
# --------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.935646	valid_1's auc: 0.905321
# [200]	training's auc: 0.957168	valid_1's auc: 0.919447
# [300]	training's auc: 0.968538	valid_1's auc: 0.930342
# [400]	training's auc: 0.97581	valid_1's auc: 0.939654
# [500]	training's auc: 0.979474	valid_1's auc: 0.948965
# [600]	training's auc: 0.983039	valid_1's auc: 0.953062
# [700]	training's auc: 0.984633	valid_1's auc: 0.954075
# [800]	training's auc: 0.987151	valid_1's auc: 0.958003
# [900]	training's auc: 0.988224	valid_1's auc: 0.957918
# [1000]	training's auc: 0.989705	valid_1's auc: 0.960262
# Early stopping, best iteration is:
# [990]	training's auc: 0.989743	valid_1's auc: 0.960325
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.932451	valid_1's auc: 0.914189
# [200]	training's auc: 0.952862	valid_1's auc: 0.934882
# [300]	training's auc: 0.966032	valid_1's auc: 0.946643
# [400]	training's auc: 0.973522	valid_1's auc: 0.952682
# [500]	training's auc: 0.978783	valid_1's auc: 0.959058
# [600]	training's auc: 0.982667	valid_1's auc: 0.963535
# [700]	training's auc: 0.985665	valid_1's auc: 0.967652
# [800]	training's auc: 0.987675	valid_1's auc: 0.968285
# [900]	training's auc: 0.988971	valid_1's auc: 0.968391
# [1000]	training's auc: 0.990667	valid_1's auc: 0.970418
# [1100]	training's auc: 0.99185	valid_1's auc: 0.972234
# [1200]	training's auc: 0.992701	valid_1's auc: 0.973269
# Early stopping, best iteration is:
# [1184]	training's auc: 0.992525	valid_1's auc: 0.973501
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.935295	valid_1's auc: 0.88053
# [200]	training's auc: 0.958118	valid_1's auc: 0.89786
# [300]	training's auc: 0.96974	valid_1's auc: 0.90572
# [400]	training's auc: 0.977785	valid_1's auc: 0.913496
# [500]	training's auc: 0.982651	valid_1's auc: 0.915508
# [600]	training's auc: 0.98567	valid_1's auc: 0.921208
# [700]	training's auc: 0.987296	valid_1's auc: 0.922246
# Early stopping, best iteration is:
# [620]	training's auc: 0.98639	valid_1's auc: 0.923072
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.932694	valid_1's auc: 0.888941
# [200]	training's auc: 0.95611	valid_1's auc: 0.909894
# [300]	training's auc: 0.969229	valid_1's auc: 0.919746
# [400]	training's auc: 0.97656	valid_1's auc: 0.931208
# [500]	training's auc: 0.980857	valid_1's auc: 0.936992
# [600]	training's auc: 0.984399	valid_1's auc: 0.941992
# [700]	training's auc: 0.986362	valid_1's auc: 0.945
# Early stopping, best iteration is:
# [686]	training's auc: 0.98637	valid_1's auc: 0.945614
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.93129	valid_1's auc: 0.913517
# [200]	training's auc: 0.95636	valid_1's auc: 0.928665
# [300]	training's auc: 0.968891	valid_1's auc: 0.939788
# [400]	training's auc: 0.977071	valid_1's auc: 0.946653
# [500]	training's auc: 0.981344	valid_1's auc: 0.950551
# [600]	training's auc: 0.983977	valid_1's auc: 0.955021
# [700]	training's auc: 0.986875	valid_1's auc: 0.956886
# [800]	training's auc: 0.988435	valid_1's auc: 0.959407
# [900]	training's auc: 0.990038	valid_1's auc: 0.962034
# [1000]	training's auc: 0.991082	valid_1's auc: 0.962564
# [1100]	training's auc: 0.99215	valid_1's auc: 0.964047
# Early stopping, best iteration is:
# [1061]	training's auc: 0.991914	valid_1's auc: 0.964597
# Average of 5 splits accuracy score : 0.8955 | f1 score : 0.8655 | roc score : 0.9532
# (0.9532, None)

# %%
val = cross_validation(X,y,best_params,5, xtest=xtest)[1]
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.919359	valid_1's auc: 0.795017
# [200]	training's auc: 0.938818	valid_1's auc: 0.808953
# [300]	training's auc: 0.95362	valid_1's auc: 0.805152
# Early stopping, best iteration is:
# [219]	training's auc: 0.940866	valid_1's auc: 0.812753
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.915972	valid_1's auc: 0.841132
# Early stopping, best iteration is:
# [36]	training's auc: 0.870666	valid_1's auc: 0.851267
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.920606	valid_1's auc: 0.775847
# Early stopping, best iteration is:
# [54]	training's auc: 0.90183	valid_1's auc: 0.786186
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.913986	valid_1's auc: 0.852373
# Early stopping, best iteration is:
# [99]	training's auc: 0.913484	valid_1's auc: 0.854492
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.908867	valid_1's auc: 0.864407
# [200]	training's auc: 0.931879	valid_1's auc: 0.869915
# Early stopping, best iteration is:
# [174]	training's auc: 0.923884	valid_1's auc: 0.87322
# Average of 5 splits accuracy score : 0.8795 | f1 score : 0.4026 | roc score : 0.8356

# %%
samp_sub = pd.read_csv("dataset/sample_submission.csv")
samp_sub["Attrition"] = val
samp_sub.to_csv("est_sub_lgb_param_cv.csv", index=False)
